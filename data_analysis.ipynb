# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")
dataset = pd.concat(objs = [train_data, test_data], axis = 0)

# %%
dataset.head().T
# Out:
#                                                          0  \
# Unnamed: 0                                               0
# id                                                   70172
# Gender                                                Male
# Customer Type                               Loyal Customer
# Age                                                     13
# Type of Travel                             Personal Travel
# Class                                             Eco Plus
# Flight Distance                                        460
# Inflight wifi service                                    3
# Departure/Arrival time convenient                        4
# Ease of Online booking                                   3
# Gate location                                            1
# Food and drink                                           5
# Online boarding                                          3
# Seat comfort                                             5
# ...

# %%
sns.set_theme(style = 'whitegrid', palette = 'bright')

# %%
plt.figure(figsize=(6, 4))
ax = sns.countplot(data = dataset, x = 'satisfaction')
plt.title('Bar Plot of Satisfaction')
plt.xlabel('Satisfaction')
plt.ylabel('Count')
plt.show()

# %%
numeric_features = dataset.select_dtypes(include=np.number)
numeric_features.shape
# Out:
# (129880, 20)

# %%
def plot_histogram(feature):
    plt.hist(dataset[feature], bins = 50)
    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(feature))
    plt.show()

# %%
numeric_features.columns
# Out:
# Index(['Unnamed: 0', 'id', 'Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
numeric_features = numeric_features.drop(['Unnamed: 0', 'id'], axis=1)

# %%
numeric_features.columns
# Out:
# Index(['Age', 'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
sns.histplot(data=numeric_features, x='Age', binwidth=2, kde=True)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=numeric_features, x='Flight Distance', binwidth=30, kde=True)
# Out:
# <AxesSubplot: xlabel='Flight Distance', ylabel='Count'>

# %%
sns.histplot(data=numeric_features, x='Departure Delay in Minutes', binwidth=2, kde=True)
plt.xlim(0, 80)
# Out:
# (0.0, 80.0)
